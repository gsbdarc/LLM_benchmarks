# %%
from openai import OpenAI
from typing import Type
import os
import base64
from pdf2image import convert_from_path
from dotenv import load_dotenv
from io import BytesIO
from pydantic import BaseModel, Field
import json

import Validity_Functions

# %%
pdf_path = "/zfs/projects/students/ltdarc-usf-intern-2025/data/Arizona_Republic_Sun__Dec_17__2000_ (15).pdf"

# %%
def pdf_to_b64(pdf_path: str) -> str:
    """ Converts pdf image to b64."""
    pages = convert_from_path(pdf_path, first_page=1, last_page=1, dpi=100)
    buffer = BytesIO()
    pages[0].save(buffer, format="PNG")
    img_bytes = buffer.getvalue()
    img_b64 = base64.b64encode(img_bytes).decode()

    return img_b64

# %%
load_dotenv("/zfs/projects/students/ltdarc-usf-intern-2025/.env")
# Out:
# True

# %%
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

# %%
model = "gpt-4o-mini"

# %%
role_prompt = "You are a metadata extraction assistant that reading the TV guides of newspapers."

# %%
content_prompt = """Look at this newspaper page and extract two fields:
1. The name of the newspaper
2. The publication date (do not include day of week)

Return your answer ONLY as a valid JSON object with the following keys:
  - newspaper
  - date

Example:
{
  "newspaper": "The New York Times",
  "date": "January 5, 2023"
}
"""

# %%
class MetaData(BaseModel):
    newspaper_name: str
    publication_date: str

# %%
def call_llm(b64: str, model: str, role_prompt: str, content_prompt: str, structured_output: Type[BaseModel]) -> BaseModel:
    """Feeds B64 image into LLM and returns structured JSON as MetaData."""
    client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

    response = client.responses.parse(
        model=model,
        input=[
            {"role": "system", "content": [{"type": "input_text", "text": role_prompt}]},
            {
                "role": "user",
                "content": [
                    {"type": "input_text", "text": content_prompt},
                    {
                        "type": "input_image",
                        "image_url": f"data:image/png;base64,{b64}",  # ✅ just the string!
                    },
                ],
            },
        ],
        text_format=structured_output,
    )

    return response.output_parsed

# %%
b64 = pdf_to_b64(pdf_path)
call_llm(b64, model, role_prompt, content_prompt, MetaData)
# Out:
# MetaData(newspaper_name='Arizona Republic', publication_date='December 17, 2000')

# %%
data_path='/zfs/projects/students/ltdarc-usf-intern-2025/data'

index = Validity_Functions.make_index(data_path)

# %%
results = dict()

for idx, row in index.iterrows():
    pdf_path = row["pdf_files"]
    b64 = pdf_to_b64(pdf_path)

    output = call_llm(b64, model, role_prompt, content_prompt, MetaData)
    results[idx] = output

# %%
print(results)
# Out:
# {0: MetaData(newspaper_name='Arizona Republic', publication_date='December 17, 2000'), 1: MetaData(newspaper_name='Austin American-Statesman', publication_date='August 3, 2014'), 2: MetaData(newspaper_name='Austin American-Statesman', publication_date='February 22, 2015'), 3: MetaData(newspaper_name='Austin American-Statesman', publication_date='January 12, 2014'), 4: MetaData(newspaper_name='Austin American-Statesman', publication_date='November 23, 2014'), 5: MetaData(newspaper_name='Chicago Tribune', publication_date='May 28, 1995'), 6: MetaData(newspaper_name='Chicago Tribune', publication_date='October 30, 1994'), 7: MetaData(newspaper_name='Daily News', publication_date='April 13, 2008'), 8: MetaData(newspaper_name='Daily News', publication_date='April 25, 2010'), 9: MetaData(newspaper_name='Daily News', publication_date='June 17, 2012'), 10: MetaData(newspaper_name='Daily News', publication_date='June 9, 2013'), 11: MetaData(newspaper_name='Daily News', publication_date='March 11, 2012'), 12: MetaData(newspaper_name='Daily News', publication_date='March 30, 2014'), 13: MetaData(newspaper_name='Daily News', publication_date='May 15, 2016'), 14: MetaData(newspaper_name='Daily News', publication_date='October 14, 2007'), 15: MetaData(newspaper_name='Daily News', publication_date='October 18, 2009'), 16: MetaData(newspaper_name='Honolulu Star-Advertiser', publication_date='October 9, 2016'), 17: MetaData(newspaper_name='Honolulu Star-Advertiser', publication_date='October 9, 2016'), 18: MetaData(newspaper_name='Messenger-Inquirer', publication_date='October 12, 1997'), 19: MetaData(newspaper_name='Statesman Journal', publication_date='January 21, 1999'), 20: MetaData(newspaper_name='Statesman Journal', publication_date='November 8, 1998'), 21: MetaData(newspaper_name='Statesman Journal', publication_date='September 5, 1999'), 22: MetaData(newspaper_name='The Arizona Republic', publication_date='March 5, 2000'), 23: MetaData(newspaper_name='The Californian', publication_date='May 31, 1998'), 24: MetaData(newspaper_name='The Honolulu Advertiser', publication_date='February 9, 1997'), 25: MetaData(newspaper_name='The Honolulu Advertiser', publication_date='March 21, 2004'), 26: MetaData(newspaper_name='The Honolulu Advertiser', publication_date='March 9, 2003'), 27: MetaData(newspaper_name='The Honolulu Advertiser', publication_date='May 26, 2002'), 28: MetaData(newspaper_name='The Honolulu Advertiser', publication_date='September 28, 1997'), 29: MetaData(newspaper_name='The Kansas City Star', publication_date='April 3, 2005'), 30: MetaData(newspaper_name='The Kansas City Star', publication_date='September 15, 2002'), 31: MetaData(newspaper_name='The Monitor', publication_date='November 6, 1994'), 32: MetaData(newspaper_name='The News Tribune (Tacoma, Washington)', publication_date='March 27, 2011'), 33: MetaData(newspaper_name='The Palm Beach Post', publication_date='May 22, 1994'), 34: MetaData(newspaper_name='The Sentinel', publication_date='June 29, 1997')}
