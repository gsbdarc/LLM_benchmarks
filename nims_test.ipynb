# %%
from openai import OpenAI

client = OpenAI(
    base_url="http://yen-gpu4:8000/v1",
    api_key="not-used"  # NIM doesn't require a client-side key
)

response = client.chat.completions.create(
    model="google/gemma-4-31b-it",
    messages=[
        {"role": "user", "content": "Summarize the key ideas behind LoRA fine-tuning."}
    ],
    max_tokens=256
)

print(response.choices[0].message.content)
# Out:
# **LoRA (Low-Rank Adaptation)** is a technique used to fine-tune massive AI models (like LLMs or Diffusion models) efficiently. Instead of updating all the billions of parameters in a model, LoRA freezes the original weights and adds a tiny number of trainable parameters.
#
# Here is a summary of the key ideas behind it:
#
# ### 1. The Problem: The "Parameter Explosion"
# Traditional fine-tuning requires updating every single weight in a model. For a model with 70 billion parameters, you would need to store and calculate gradients for all 70 billion weights. This requires massive amounts of VRAM and storage, making it impossible for most people to do on consumer hardware.
#
# ### 2. The Core Hypothesis: "Intrinsic Dimension"
# The creators of LoRA hypothesized that when a model learns a new task, the change in the weights ($\Delta W$) doesn't actually need to happen across the entire high-dimensional space. Instead, the "meaningful" change happens in a much lower-dimensional subspace.
#
# In simpler terms: **You don't need to move every knob on the machine to change the output; you only need to move a few key levers.**
#
# ### 3. The Mechanism:
